# %% [markdown]
# # Part I: lists and loops

# %%
#1) Create a list with the names of the top 10 CO₂ emitting countries (in order by total emissions)

# %%
Top10_list=['China', 'United States', 'India', 'Russia', 'Japan', 'Iran', 'Indonesia', 'Saudi Arabia', 'South korea', 'Germany']
Top10_list
# Out:
# ['China',
#  'United States',
#  'India',
#  'Russia',
#  'Japan',
#  'Iran',
#  'Indonesia',
#  'Saudi Arabia',
#  'South korea',
#  'Germany']

# %%
print(type(Top10_list))
# Out:
# <class 'list'>

# %%
#2) Have Python tell you how many countries there are by examining your list

# %%
len(Top10_list)
# Out:
# 10

# %%
#3) Use slicing to display the first three countries (the top emitters)

# %%
Top10_list[0:3]
# Out:
# ['China', 'United States', 'India']

# %%
#4) Iterate through your countries and print the country name only if it has an a in the name

# %%
for i in Top10_list:
    A= i.count('a')
    if  A ==1:
        print(i)
# Out:
# China
# United States
# India
# Russia
# Iran
# Indonesia
# South korea
# Germany

# %% [markdown]
# # Part II: Dictionaries

# %%
#1) Now create a dictionary that maps each country name to its annual CO₂ emissions

# %%
Top_10 = {'China':13124.70,'United States':4632.16,'India':3153.83,'Russia':2009.15,'Japan':972.27,'Iran':828.99,'Indonesia':812.20,'Saudi Arabia':652.51,'South Korea':588.01,'Germany':579.94}
Top_10
# Out:
# {'China': 13124.7,
#  'United States': 4632.16,
#  'India': 3153.83,
#  'Russia': 2009.15,
#  'Japan': 972.27,
#  'Iran': 828.99,
#  'Indonesia': 812.2,
#  'Saudi Arabia': 652.51,
#  'South Korea': 588.01,
#  'Germany': 579.94}

# %%
print(type(Top_10))
# Out:
# <class 'dict'>

# %%
#2) Use your dictionary to look up the United States’ emissions

# %%
US= Top_10['United States']
print(US)
# Out:
# 4632.16

# %%
#3) Loop through the data and create a list of countries whose emissions are greater than 1,000 million metric tons per year

# %%
for i in Top_10:
    E = Top_10[i]
    if E >= 1000:
        print(i)
# Out:
# China
# United States
# India
# Russia

# %%
# 4) Now add Brazil to your dictionary

# %%
Top_10['Brazil']= 491.47
Top_10
# Out:
# {'China': 13124.7,
#  'United States': 4632.16,
#  'India': 3153.83,
#  'Russia': 2009.15,
#  'Japan': 972.27,
#  'Iran': 828.99,
#  'Indonesia': 812.2,
#  'Saudi Arabia': 652.51,
#  'South Korea': 588.01,
#  'Germany': 579.94,
#  'Brazil': 491.47}

# %% [markdown]
# # Part III: Functions

# %%
# 1. Write a function to convert temperature from kelvin to celsius and celsius to kelvin

# %%
def k_c(k):
    c = k - 273.15
    return c

# %%
def c_k(c):
    k = c + 273.15
    return k

# %%
# 2. Write a function to convert temperature to fahrenheit
#Include an optional keyword argument to specify whether the input is in celcius or kelvin.
#Call your previously defined functions if necessary.

# %%
def to_f(t, unit='celsius'):
    if unit == 'celsius':
       return t * 9/5 + 32
    elif unit =='kelvin':
       return k_c(t) * 9/5 + 32
    else:
       raise Error ('Error,check the unit')

# %%
#3. Check that the outputs are sensible

# %%
to_f(0,'kelvin')
# Out:
# -459.66999999999996

# %%
to_f(0)
# Out:
# 32.0

# %%
to_f(25,'celsius')
# Out:
# 77.0

# %%
#4.Now write a function that converts from farenheit 
#and uses a keyword argument to specify whether you want the output in celcius or kelvin

# %%
def f_to(t,unit='celsius'):
    if unit =='celsius':
        c = (t -32) * 5/9  
        return c
    if unit =='kelvin':
        c = (t -32) * 5/9 + 273.15
        return c

# %%
f_to(65)
# Out:
# 18.333333333333332

# %%
f_to(0,'kelvin')
# Out:
# 255.3722222222222

# %%
#5. Write a function that takes two arguments (feet and inches) and returns height in meters

# %%
def to_m(feet, inches):
    return feet * 0.3048 + inches * 0.0254

# %%
to_m(1,2)
# Out:
# 0.3556

# %%
#6.Write a function takes one argument (height in meters) and returns two arguments (feet and inches)

# %%
def tof_i(m):
    ans= m * 3.28084
    f = int(ans)
    i = round((ans- f)* 12, 2)
    return f,i

# %%
tof_i(1)
# Out:
# (3, 3.37)

# %%
#7.Verify that the “round trip” conversion from and back to meters is consistent

# %%
to_m(10,10)
# Out:
# 3.302

# %%
tof_i(3.302)
# Out:
# (10, 10.0)

# %%
to_m(5,5)
# Out:
# 1.651

# %%
tof_i(1.651)
# Out:
# (5, 5.0)

# %%
to_m(1,1)
# Out:
# 0.3302

# %%
tof_i(0.3302)
# Out:
# (1, 1.0)
